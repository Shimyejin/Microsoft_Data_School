# %% [markdown]
# #### 웹페이지 요청 및 응답받기
# * `requests.get(url)`
#     *  -> Response 객체 리턴
# * Response  객체의 주요 속성
#     * `status_code` : 요청 성공 여부
#         * 200 : 요청이 성공적으로 처리됨
#         * 4XX : 클라이언트 오류
#             * 403 : 권한 없음
#             * 404 : Not Found(요청한 리소스를 찾을 수 없음)
#         * 5XX : 서버 오류
#             * 500 : 서버 내부 오류
#     * `text` : 응답 본문 (utf-8로 변환된 문자열 형태로 제공)
#     * `content` : 응답 본문 (byte형태로 제공)

# %%
# -----------------------------------------
# 웹페이지 요청 및 응답받기
# -----------------------------------------
import requests
url = 'https://finance.naver.com/news/mainnews.naver'
response = requests.get(url)

# -----------------------------------------
# 요청 성공여부 확인
# -----------------------------------------
status_code = response.status_code 

# -----------------------------------------
# 응답받은 웹문서
# -----------------------------------------
html = response.text

print(status_code)
html # ==> print(html)로 출력 시 vscode 다운될 수 있음
# Out:
# 200
# '<!--  global include -->\n\n\t\n\t\n\t\n\t\n<html lang=\'ko\'>\n<head>\n\n\n\t\n\t\n\t\t\n\t\t\t\n\t\t\t\t<title>네이버페이 증권</title>\n\t\t\t\n\t\t\t\n\t\t\n\t\n\n\n\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta name="apple-mobile-web-app-title" content="네이버페이 증권" />\n\n\n\n\n\n\t\n    \n        <meta property="og:url" content="http://finance.naver.com/news/mainnews.naver"/>\n        \n\t\t\t\n\t\t    \n\t\t    \t<meta property="og:title" content="주요뉴스 : 네이버페이 증권"/>\n\t\t     \n\t\t\n\t\t\n\t\t\t\n\t\t\t   <meta property="og:description" content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳"/>\n\t\t    \n\t\t    \n\t\t\n\t\t \n\t\t\t\n\t\t\t    <meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>\n\t\t    \n\t\t    \n\t\t\n    \n\n<meta property="og:type" content="article"/>\n<meta property="og:article:thumbnailUrl" content=""/>\n<meta property="og:article:author" content="네이버페이 증권"/>\n<meta property="og:article:author:url" content="http://FINANCE.NAVER.COM"/>\n\n\n\n\n\n\n<link rel=\'stylesheet\' type=\'text/css\' href=\'https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/finance_header.css\'>\n\n\t\n\t\n\t\n\t\n\t\t\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/newstock.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/common.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/layout.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/main.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/newstock2.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/newstock3.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/world.css">\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/js/jindo.min.ns.1.5.3.euckr.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/js/release/common.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/js/jindoComponent/jindo.Component.1.0.3.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/js/nhn.autocomplete.stock.js"></script>\n\t\t\t\n\t\t\n\n\t\t\n\t\n\n<script>\n\tvar ieVersion = (function () {\n        var version = -1;\n        if (\n          navigator.appName == \'Microsoft Internet Explorer\' &&\n          navigator.userAgent.toLowerCase().indexOf(\'msie\') != -1 &&\n          new RegExp(\'MSIE ([0-9]{1,}[\\./0-9]{0,})\').exec(navigator.userAgent) != null\n        ) {\n          version = parseInt(RegExp.$1);\n        }\n        return version;\n      })();\n</script>\n\t\n\n\t<link rel="shortcut icon" href="https://ssl.pstatic.net/imgstock/favi/favicon.ico" type="image/x-icon">\n\t\n\t<script type="text/javascript">\n    (function(){\n\t\tdocument.write(\n\t\t\t\t[\n\t\t\t\t\t\'<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/imgstock/favi/favicon-96x96.png"/>\',\n\t\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/imgstock/favi/favicon-180x180.png"/>\',\n\t\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/imgstock/favi/favicon-192x192.png"/>\',\n\t\t\t\t\t\'<link rel="icon" type="image/png" sizes="16x16" href="https://ssl.pstatic.net/imgstock/favi/favicon-16x ...

# %% [markdown]
# #### html문서에서 요소 추출
# * BeautisulSoup 객체 생성
#     * `BeautifulSoup(html문서, html파서)`
# * 요소 추출
#     * `select_one(선택자)`
#         * 선택자로 요소 1개 추출
#         * 동일한 선택자를 가진 요소가 여러개인 경우 가장 첫번째 요소만 추출
#     * `select(선택자)`
#         * 모든 요소를 리스트로 추출

# %%
# -----------------------------------------
# BeautifulSoup 객체 생성
# -----------------------------------------

from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')


# -----------------------------------------
# html 문서에서 뉴스 첫번째 뉴스 제목 추출하기
# -----------------------------------------
first_article = soup.select_one(".articleSubject > a")


# -----------------------------------------
# html 문서에서 뉴스 모든 뉴스 제목 추출하기
# -----------------------------------------
article_list = soup.select(".articleSubject > a")


print(first_article)
print(article_list)
# Out:
# <a href="/news/news_read.naver?article_id=0005184744&amp;office_id=008&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">최상목 매수 논란 미국 채권…일본은 팔고 한국은 사고</a>
# [<a href="/news/news_read.naver?article_id=0005184744&amp;office_id=008&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">최상목 매수 논란 미국 채권…일본은 팔고 한국은 사고</a>, <a href="/news/news_read.naver?article_id=0005122932&amp;office_id=015&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">'나홀로 돈 벌었다'…미·중 관세 전쟁 '대피처'로 뜬 나라</a>, <a href="/news/news_read.naver?article_id=0001206848&amp;office_id=215&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">"저가매수 신중해라"…과도한 낙관은 '금물'</a>, <a href="/news/news_read.naver?article_id=0001206847&amp;office_id=215&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">"진정한 바닥 오지 않았다"…추가 하락 '경고등'</a>, <a href="/news/news_read.naver?article_id=0005481116&amp;office_id=009&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">땡큐 트럼프! 中 협상 가능성에 가상자산 환호…비트코인 9만3000달러 돌파</a>, <a href="/news/news_read.naver?article_id=0005481114&amp;office_id=009&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">9.3만弗 회복한 비트코인...금 따라갈까 [매일코인]</a>, <a href="/news/news_read.naver?article_id=0004477427&amp;office_id=011&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">美 재무장관 한마디에…韓 대표 대기업 줄줄이 강세 [주식 초고수는 지금]</a>, <a href="/news/news_read.naver?article_id=0001072771&amp;office_id=417&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">고태봉 iM증권 본부장 "한국, 생존법은 피지컬AI… 골든타임 남아"</a>, <a href="/news/news_read.naver?article_id=0005184673&amp;office_id=008&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">'관세전쟁' 한 발 뺀 트럼프…반도체·장비주 줄줄이 기지개</a>, <a href="/news/news_read.naver?article_id=0004477417&amp;office_id=011&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">대선 승리에 베팅했나…민주당 공약에 전력株 급등 [이런국장 저런주식]</a>, <a href="/news/news_read.naver?article_id=0002461443&amp;office_id=016&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">외인 이탈에도 증권가 “코스피 2600 돌파”</a>, <a href="/news/news_read.naver?article_id=0000035557&amp;office_id=648&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">검찰, 고려아연·미래에셋증권 압수수색…유상증자 부정거래 의혹 관련</a>, <a href="/news/news_read.naver?article_id=0000384353&amp;office_id=629&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">'IPO 5수생' 빗썸, 거래소-신사업 분리안 묘수될까</a>, <a href="/news/news_read.naver?article_id=0001206822&amp;office_id=215&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">"미국보다 낫다?"…글로벌 자금, 韓증시로 눈 돌리나 [진짜 주식 2부]</a>, <a href="/news/news_read.naver?article_id=0001206821&amp;office_id=215&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">검찰, '고려아연 유상증자 주관사' 미래에셋증권 압수수색</a>, <a href="/news/news_read.naver?article_id=0002461349&amp;office_id=016&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">‘머스크 테슬라 귀환’ 기대에 LG엔솔 주가도 강세 [종목Pick]</a>, <a href="/news/news_read.naver?article_id=0002461345&amp;office_id=016&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">반도체주 美관세 우려 완화에 줄상승…삼성전자 1.27%↑[종목Pick]</a>, <a href="/news/news_read.naver?article_id=0002461341&amp;office_id=016&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">누그러진 트럼프에 코스피 1%대 강세…2510대 탈환 [투자360]</a>, <a href="/news/news_read.naver?article_id=0000035554&amp;office_id=648&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">HD현대일렉트릭, 역대급 실적에도 주가는 급락?…증권가 분석 엇갈려</a>, <a href="/news/news_read.naver?article_id=0002948378&amp;office_id=119&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1"> 미중 관세전쟁 완화 기대감에…코스피 2500선 탈환[트럼프 스트레스]</a>]

# %% [markdown]
# #### 요소에서 원하는 부분 추출
# * `text`
#     * 요소의 텍스트 추출
# * `attrs["속성명"]`
#     * 특정 속성 추출

# %%
first_article
# Out:
# <a href="/news/news_read.naver?article_id=0005184744&amp;office_id=008&amp;mode=mainnews&amp;type=&amp;date=2025-04-23&amp;page=1">최상목 매수 논란 미국 채권…일본은 팔고 한국은 사고</a>

# %%
first_article.text
# Out:
# '최상목 매수 논란 미국 채권…일본은 팔고 한국은 사고'

# %%
first_article.attrs
# Out:
# {'href': '/news/news_read.naver?article_id=0005184744&office_id=008&mode=mainnews&type=&date=2025-04-23&page=1'}

# %%
first_article.attrs["href"]
# Out:
# '/news/news_read.naver?article_id=0005184744&office_id=008&mode=mainnews&type=&date=2025-04-23&page=1'
