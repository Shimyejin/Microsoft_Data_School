# %% [markdown]
# * https://drive.google.com/file/d/1todwi6NRInDwkFY24sSneP0c7RGTNTms/view?usp=sharing

# %% [markdown]
# #### konlpy 정상동작 확인

# %%
from konlpy.tag import Okt

okt = Okt()
print(okt.morphs("KoNLPy가 정상 설치되었는지 확인 중입니다."))
# Out:
# ['KoNLPy', '가', '정상', '설치', '되었는지', '확인', '중', '입니다', '.']

# %%
import jpype
if not jpype.isJVMStarted():
    jpype.startJVM()
print("JPype와 JVM이 정상 작동 중입니다.")
# Out:
# JPype와 JVM이 정상 작동 중입니다.

# %%
import pandas as pd

# %% [markdown]
# #### 데이터 준비

# %%
# ------------------------------
#   파일 경로
# ------------------------------
data_file = 'data\\네이버증권뉴스\\주요뉴스_모든페이지_2025-04-23_1745395304.csv'

# ------------------------------
#   불러올 컬럼명
# ------------------------------
col_name = 'title'

# ------------------------------
#   데이터 불러오기
# ------------------------------
data = pd.read_csv(data_file).loc[:,col_name].dropna()

# ------------------------------
#   내용 컬럼을 하나의 문장으로 합치기
# ------------------------------
text = ' '.join(data)
text
# Out:
# '한발 물러선 트럼프에 코스피 ‘성큼’…단숨에 2520대 복귀 [투자360] 국고채 10년물 금리, 3년 2개월래 최저치…미 4월 S&P PMI 대기(종합) 관세 전쟁에도 급증하는  `빚투`…삼전·SK하닉 증거금률 대폭 올랐다  "머스크 정신 차리나"…테슬라 실적부진에도 이차전지株 \'껑충\'[살까팔까] 최악 실적에도 테슬라 주가는 바닥 탈출···2분기 연속 어닝쇼크 무시 2500선 재차 넘은 코스피...\'실적·정책\'에 순환매 장세 탄력 올 들어 18조 내다판 외국인...이 종목은 지분율 확 높였다 관세에 떨던 반도체株, 美中 갈등 완화 기대에 ‘활짝’…SK하이닉스 4%↑[투자360] 캐시 우드의 아크인베스트, 솔라나 첫 매수 "단타로 돈 벌자" 불개미 달려들었다…회전율 200% 넘긴 정치 테마주 커지는 글로벌 원자력 시장···오르는 국내 원전주 안철수 후보 2차 경선行에…관련주 또 \'들썩\' [이런국장 저런주식] 테슬라 시간외 급등에…국내 이차전지株 \'들썩\'(종합) 반도체·이차전지 모두 강세…코스피 2500 탈환 ‘한화에어로 99%·이마트 45%’ 연초比 영업익 전망 상향株 주목…“관세 공포 정점 코스피, 실적 민감도↑”[투자360] “글로벌 기업들이 공장 짓는 곳”… 관세 전쟁에도 오르는 인도 증시 \'유증 부정거래 의혹\' 고려아연, 검찰 압수수색에 주가 \'출렁\'(종합) 안철수, 국민의힘 2차 경선 진출…써니전자·안랩 주가 강세(종합) 이재명 테마주 DSC인베, 주가 오르자 임원들 수십억 매도 SCHD, 美서 평가 하향조정되고 자금 빠지고…서학개미 사랑은 꾸준 민주당 ‘퇴직연금 기금화’ 추진에 PE업계 ‘반색’ “‘투자경고·위험’ 종목 80% 정치테마주…주가 변동률 ‘코스피 7배 122%” [투자360] 日 시총 1천억원 미만 상폐 추진…"자본시장 전환점" PBR 0.1 기업 정리한다는데…청산 가치보다 낮은 기업 어디? "금값은 너무 올랐어" 대안은 \'이것\'?…반등 기대→돈 몰린다 달러 가치 회복 나선 미국…지속되는 환율 ‘레인지 장’ ‘머스크 복귀 예고’에 테슬라 이어 韓 2차전지주도 강세 금감원 제동에도 유증 재도전 나선 스맥, 다윗의 골리앗 인수 가능할까 5년만에 역성장...편의점, 해외 노린다 [마켓딥다이브] 트럼프 관세전쟁에 \'셀 아메리카\'…유럽펀드로 갈아타는 투자자들 증여 소식에 한미반도체 13% 상승 \'훨훨\' [줍줍리포트]  "풍산, 나홀로 저평가…인적분할 시 기업가치 두 배 뛴다"[마켓칼럼] "주가 변동률만 120%"…거래소, 정치인 테마株 \'투자 주의보\' BYD에 밀린 테슬라…머스크 컴백에도 불안 [테크톡톡] "점심시간 1시간 엄수" 공지에…여의도 증권맨들 \'초긴장\' [돈앤톡] 테슬라 시간외 급등에…국내 이차전지株 \'들썩\' 투자경고 이상 종목 중 절반이 \'정치테마주\'…121% 변동에 \'투자주의보\' 과열된 정치 테마주 폭등락… 거래소 “불공정거래, 강력 대처” ‘시장 눈치’ 트럼프에 미 10년물 금리 하락…국고채도 10년물 강세 최상목 매수 논란 미국 채권…일본은 팔고 한국은 사고 \'나홀로 돈 벌었다\'…중국 탈출 러시에 \'대피처\'로 뜬 나라 "저가매수 신중해라"…과도한 낙관은 \'금물\' "진정한 바닥 오지 않았다"…추가 하락 \'경고등\' 땡큐 트럼프! 中 협상 가능성에 가상자산 환호…비트코인 9만3000달러 돌파 9.3만弗 회복한 비트코인...금 따라갈까 [매일코인] \'ESG공시\' 시점 다시 안갯속...금융당국 "해외도 확정 안해" 美 재무장관 한마디에…韓 대표 대기업 줄줄이 강세 [주식 초고수는 지금] 고태봉 iM증권 본부장 "한국, 생존법은 피지컬AI… 골든타임 남아" \'관세전쟁\' 한 발 뺀 트럼프…반도체·장비주 줄줄이 기지개 대선 승리에 베팅했나…민주당 공약에 전력株 급등 [이런국장 저런주식] 금융당국, 삼부토건 주가조작 의혹 검찰로 넘긴다 외인 이탈에도 증권가 “코스피 2600 돌파” 검찰, 고려아연·미래에셋증권 압수수색…유상증자 부정거래 의혹 관련 \'IPO 5수생\' 빗썸, 거래소-신사업 분리안 묘수될까 \'최대주주 공개매수\' 케이씨텍, 10% 상승 [줍줍리포트] "미국보다 낫다?"…글로벌 자금, 韓증시로 눈 돌리나 [진짜 주식 2부] 옵트론텍, 美 완성차 업체에 자율주행용 고화질 렌즈 공급 개시 검찰, \'고려아연 유상증자 주관사\' 미래에셋증권 압수수색 ‘머스크 테슬라 귀환’ 기대에 LG엔솔 주가도 강세 [종목Pick]  한국투자증권 "금호석유화학 합성고무 반등, 화학 최선호주"[아침밥] 반도체주 美관세 우려 완화에 줄상승…삼성전자 1.27%↑[종목Pick] 누그러진 트럼프에 코스피 1%대 강세…2510대 탈환 [투자360] HD현대일렉트릭, 역대급 실적에도 주가는 급락?…증권가 분석 엇갈려  미중 관세전쟁 완화 기대감에…코스피 2500선 탈환[트럼프 스트레스]  한투증권 "에코프로비엠, 상승 기대… 삼성SDI가 변수"[아침밥] 美中해빙 모드에 테슬라 호재까지… 2차전지주 반등[핫종목] 한화에어로 0.23% 오르면 현대차 역전…넘버5 변동 초읽기  [투자360] 1분기 어닝쇼크에 “5월부터 테슬라에 집중”…테슬람 떠날라, 달래기 나선 머스크 [투자360] 머스크 "5월부터 테슬라에 집중"…국내 2차전지주도 \'활짝\' 에이프로젠, \'초고순도 다중항체 제조 플랫폼\' 특허 출원 브릿지바이오 5영업일 하한가…신신제약, 소마젠 약진[바이오맥짚기] 미·중 갈등에 시름 깊어지는데 인도 투자자는 안도 [투자360] 인크레더블버즈, 스킨부스터 대체제 18조 성장 전망 ‘바이오스티뮬레이터 시장’ 수혜 기대 미·중 갈등 완화 기대감에 상승 출발…코스피 2500선 탈환 지엘팜텍, 안구건조증 신약 3상 성공 소식에 상한가 직행[핫스탁] 전력기기 기업 역대급 매출에도 9% 뚝…美 관세 무섭네 [이런국장 저런주식] 분기 매출 1조원 달성에 도리어 급락… HD현대일렉트릭에 엇갈린 증권가 전망 "LG디스플레이, 관세 우려에도 주가 상승 기대해볼 시기"-SK "HD현대일렉트릭, 피크아웃 과한 우려는 금물...목표가 ↓" -삼성證 "왕(머스크)이 돌아온다"…테슬라, 시간 외 5%대 강세 美 재무 “무역전쟁 완화 예상”…국제유가 1%대↑[원자재&ETF뉴스] "中 태양광에 떨어진 관세 폭탄…한화솔루션·OCI홀딩스 주목"-현대차 "HD현대일렉트릭, 이익률 피크아웃 우려는 과도"-삼성 외국인들, 현대차 팔고 무섭게 사들이더니…불기둥 \'폭발\' [종목+] "전력기기 업종 밸류에이션 15% 급감…HD현대일렉트릭 목표가 6만원↓" "한방·미용 모두 잡은 동방메디컬…하반기 주가 반등 기대"-상상인 KB證 “글로벌 원전 수요 증가…현대건설·두산에너빌리티, 존재감 드러낼 것” 트럼프 "中 관세 협상 후 내려갈 것" 발언에…프리마켓 1%대 상승 "Fed 독립성 침해는 시장 신뢰 저해 요인" "이젠 테슬라에 집중" 머스크 발언에 시간외 5% 상승 에코프로비엠, 고객사 삼성SDI 유럽 점유율 하락 부정적…투자의견 ‘중립’-한국 비트코인, 9만2000달러선 회복…이제는 안전자산? 비트코인 9만 달러 재돌파…기술주와 \'디커플링\' 조짐  다시 한발 물러선 트럼프…코스피 2,500 기대해볼까[마켓뷰] 석달 만에 5000억 번 방시혁 자신감? 소속 걸그룹 “뉴진스 빼고 다 뭉쳤다”…“하이브 목표가 34만원” 가능? [종목Pick] “에코프로비엠, 전기차 시장 둔화에 관세 공포까지”…목표가↓ 관세 전쟁 완화 기대감…"韓증시, 상승 출발 전망"[굿모닝 증시] "에코프로비엠, 상승 모멘텀 많지만 유럽이 변수"[클릭 e종목] "엘앤에프, 신차 출시·고객사 확장 효과 기대"-한국 "CJ, 올리브영 역성장 우려 과도…조정시 비중확대"-대신 “HD현대일렉트릭, 수요 견조하게 유지하며 신규 수주는 증가할 것” 현대오토에버, 그룹 내 중요도 재확인 필요…목표가↓-키움 목표주가 ‘하향 조정’에도 엔비디아 주가 2% 강세…왜? [투자360] 미중 무역협상 낙관론에 美증시 반등…트럼프 "파월 해고 안해"[뉴스새벽배송] "HD현대일렉트릭, 고점 우려에 대한 시험대 올라…목표가↓"-신한 비트코인, 46일만에 9만달러선 회복…이더리움 10%대 반등 [투자360] "HD현대일렉트릭, 업황은 여전히 상승 사이클…목 ...

# %% [markdown]
# #### 문자열 정제
# * 한글만 남기기

# %%
import re
clean_text = re.sub(r'[^가-힇\s]', ' ', text)
clean_text
# Out:
# '한발 물러선 트럼프에 코스피  성큼  단숨에     대 복귀  투자     국고채   년물 금리   년  개월래 최저치 미  월         대기 종합  관세 전쟁에도 급증하는   빚투  삼전   하닉 증거금률 대폭 올랐다   머스크 정신 차리나  테슬라 실적부진에도 이차전지   껑충  살까팔까  최악 실적에도 테슬라 주가는 바닥 탈출    분기 연속 어닝쇼크 무시     선 재차 넘은 코스피    실적 정책 에 순환매 장세 탄력 올 들어   조 내다판 외국인   이 종목은 지분율 확 높였다 관세에 떨던 반도체      갈등 완화 기대에  활짝    하이닉스     투자     캐시 우드의 아크인베스트  솔라나 첫 매수  단타로 돈 벌자  불개미 달려들었다 회전율      넘긴 정치 테마주 커지는 글로벌 원자력 시장   오르는 국내 원전주 안철수 후보  차 경선 에 관련주 또  들썩   이런국장 저런주식  테슬라 시간외 급등에 국내 이차전지   들썩  종합  반도체 이차전지 모두 강세 코스피      탈환  한화에어로     이마트      연초  영업익 전망 상향  주목  관세 공포 정점 코스피  실적 민감도   투자      글로벌 기업들이 공장 짓는 곳   관세 전쟁에도 오르는 인도 증시  유증 부정거래 의혹  고려아연  검찰 압수수색에 주가  출렁  종합  안철수  국민의   차 경선 진출 써니전자 안랩 주가 강세 종합  이재명 테마주    인베  주가 오르자 임원들 수십억 매도        서 평가 하향조정되고 자금 빠지고 서학개미 사랑은 꾸준 민주당  퇴직연금 기금화  추진에   업계  반색    투자경고 위험  종목     정치테마주 주가 변동률  코스피  배        투자       시총  천억원 미만 상폐 추진  자본시장 전환점          기업 정리한다는데 청산 가치보다 낮은 기업 어디   금값은 너무 올랐어  대안은  이것   반등 기대 돈 몰린다 달러 가치 회복 나선 미국 지속되는 환율  레인지 장   머스크 복귀 예고 에 테슬라 이어    차전지주도 강세 금감원 제동에도 유증 재도전 나선 스맥  다윗의 골리앗 인수 가능할까  년만에 역성장   편의점  해외 노린다  마켓딥다이브  트럼프 관세전쟁에  셀 아메리카  유럽펀드로 갈아타는 투자자들 증여 소식에 한미반도체     상승  훨훨   줍줍리포트    풍산  나홀로 저평가 인적분할 시 기업가치 두 배 뛴다  마켓칼럼   주가 변동률만       거래소  정치인 테마   투자 주의보     에 밀린 테슬라 머스크 컴백에도 불안  테크톡톡   점심시간  시간 엄수  공지에 여의도 증권맨들  초긴장   돈앤톡  테슬라 시간외 급등에 국내 이차전지   들썩  투자경고 이상 종목 중 절반이  정치테마주       변동에  투자주의보  과열된 정치 테마주 폭등락  거래소  불공정거래  강력 대처   시장 눈치  트럼프에 미   년물 금리 하락 국고채도   년물 강세 최상목 매수 논란 미국 채권 일본은 팔고 한국은 사고  나홀로 돈 벌었다  중국 탈출 러시에  대피처 로 뜬 나라  저가매수 신중해라  과도한 낙관은  금물   진정한 바닥 오지 않았다  추가 하락  경고등  땡큐 트럼프    협상 가능성에 가상자산 환호 비트코인  만    달러 돌파    만  회복한 비트코인   금 따라갈까  매일코인      공시  시점 다시 안갯속   금융당국  해외도 확정 안해    재무장관 한마디에   대표 대기업 줄줄이 강세  주식 초고수는 지금  고태봉   증권 본부장  한국  생존법은 피지컬    골든타임 남아   관세전쟁  한 발 뺀 트럼프 반도체 장비주 줄줄이 기지개 대선 승리에 베팅했나 민주당 공약에 전력  급등  이런국장 저런주식  금융당국  삼부토건 주가조작 의혹 검찰로 넘긴다 외인 이탈에도 증권가  코스피      돌파  검찰  고려아연 미래에셋증권 압수수색 유상증자 부정거래 의혹 관련       수생  빗썸  거래소 신사업 분리안 묘수될까  최대주주 공개매수  케이씨텍      상승  줍줍리포트   미국보다 낫다   글로벌 자금   증시로 눈 돌리나  진짜 주식  부  옵트론텍    완성차 업체에 자율주행용 고화질 렌즈 공급 개시 검찰   고려아연 유상증자 주관사  미래에셋증권 압수수색  머스크 테슬라 귀환  기대에   엔솔 주가도 강세  종목       한국투자증권  금호석유화학 합성고무 반등  화학 최선호주  아침밥  반도체주  관세 우려 완화에 줄상승 삼성전자        종목      누그러진 트럼프에 코스피   대 강세     대 탈환  투자       현대일렉트릭  역대급 실적에도 주가는 급락  증권가 분석 엇갈려  미중 관세전쟁 완화 기대감에 코스피     선 탈환 트럼프 스트레스   한투증권  에코프로비엠  상승 기대  삼성   가 변수  아침밥    해빙 모드에 테슬라 호재까지   차전지주 반등 핫종목  한화에어로       오르면 현대차 역전 넘버  변동 초읽기   투자      분기 어닝쇼크에   월부터 테슬라에 집중  테슬람 떠날라  달래기 나선 머스크  투자     머스크   월부터 테슬라에 집중  국내  차전지주도  활짝  에이프로젠   초고순도 다중항체 제조 플랫폼  특허 출원 브릿지바이오  영업일 하한가 신신제약  소마젠 약진 바이오맥짚기  미 중 갈등에 시름 깊어지는데 인도 투자자는 안도  투자     인크레더블버즈  스킨부스터 대체제   조 성장 전망  바이오스티뮬레이터 시장  수혜 기대 미 중 갈등 완화 기대감에 상승 출발 코스피     선 탈환 지엘팜텍  안구건조증 신약  상 성공 소식에 상한가 직행 핫스탁  전력기기 기업 역대급 매출에도    뚝   관세 무섭네  이런국장 저런주식  분기 매출  조원 달성에 도리어 급락    현대일렉트릭에 엇갈린 증권가 전망    디스플레이  관세 우려에도 주가 상승 기대해볼 시기        현대일렉트릭  피크아웃 과한 우려는 금물   목표가     삼성   왕 머스크 이 돌아온다  테슬라  시간 외   대 강세   재무  무역전쟁 완화 예상  국제유가   대  원자재    뉴스     태양광에 떨어진 관세 폭탄 한화솔루션    홀딩스 주목  현대차    현대일렉트릭  이익률 피크아웃 우려는 과도  삼성 외국인들  현대차 팔고 무섭게 사들이더니 불기둥  폭발   종목    전력기기 업종 밸류에이션     급감   현대일렉트릭 목표가  만원    한방 미용 모두 잡은 동방메디컬 하반기 주가 반등 기대  상상인      글로벌 원전 수요 증가 현대건설 두산에너빌리티  존재감 드러낼 것  트럼프    관세 협상 후 내려갈 것  발언에 프리마켓   대 상승      독립성 침해는 시장 신뢰 저해 요인   이젠 테슬라에 집중  머스크 발언에 시간외    상승 에코프로비엠  고객사 삼성    유럽 점유율 하락 부정적 투자의견  중립  한국 비트코인   만    달러선 회복 이제는 안전자산  비트코인  만 달러 재돌파 기술주와  디커플링  조짐  다시 한발 물러선 트럼프 코스피       기대해볼까 마켓뷰  석달 만에     억 번 방시혁 자신감  소속 걸그룹  뉴진스 빼고 다 뭉쳤다   하이브 목표가   만원  가능   종목       에코프로비엠  전기차 시장 둔화에 관세 공포까지  목표가  관세 전쟁 완화 기대감   증시  상승 출발 전망  굿모닝 증시   에코프로비엠  상승 모멘텀 많지만 유럽이 변수  클릭  종목   엘앤에프  신차 출시 고객사 확장 효과 기대  한국      올리브영 역성장 우려 과도 조정시 비중확대  대신    현대일렉트릭  수요 견조하게 유지하며 신규 수주는 증가할 것  현대오토에버  그룹 내 중요도 재확인 필요 목표가  키움 목표주가  하향 조정 에도 엔비디아 주가    강세 왜   투자     미중 무역협상 낙관론에  증시 반등 트럼프  파월 해고 안해  뉴스새벽배송     현대일렉트릭  고점 우려에 대한 시험대 올라 목표가   신한 비트코인    일만에  만달러선 회복 이더리움    대 반등  투자        현대일렉트릭  업황은 여전  상승 사이클 목표가   클릭  종목  한투   엘앤에프  신차 출시 효과 및 고객사 확장  목표가  만    원 ...

# %% [markdown]
# * 블용어 사전

# %%
# -----------------------
# 외부 불용어 사전
# -----------------------

import requests

url = "https://raw.githubusercontent.com/stopwords-iso/stopwords-ko/refs/heads/master/stopwords-ko.txt"
response = requests.get(url)

# 줄 단위로 나누고, 공백 제거 후 리스트 생성
external_stopwords = [line.strip() for line in response.text.splitlines() if line.strip()]

# -----------------------
# 커스터마이즈 불용어 사전
# -----------------------
custom_stopwords = []


# -----------------------
# 최종 불용어 사전
#   외부 불용어 사전, 커스터마이즈 불용어사전 합치고 중복 제거
# -----------------------
stopwords = set(external_stopwords + custom_stopwords)

# %% [markdown]
# #### 명사 추출 및 불용어 제거
# * KoNLPy라이브러리의 형태소분석기 사용
# * KoNLPy 사용 시 자바(JDK)가 필요할 수 있으니, 환경에 따라 JDK 설치 및 JAVA_HOME 환경변수 설정이 필요할 수도 있습니다​

# %%
# ----------------------------
# 형태소 분석기로 명사만 추출
# ----------------------------

from konlpy.tag import Okt

okt = Okt()
nouns = okt.nouns(clean_text)

# ----------------------------
# 한글자인 명사와 불용어 제거
# ----------------------------

filtered_nouns = [
    n for n in nouns
    if len(n) > 1 and n not in stopwords
]

# %% [markdown]
# #### 단어 빈도 계산
# * 리스트에서 각 항목이 몇 번 나오는지 카운트

# %%
from collections import Counter

counter = Counter(filtered_nouns)  # 명사 리스트를 Counter 객체로 변환
print(counter.most_common(10))
# Out:
# [('투자', 19), ('관세', 19), ('주가', 14), ('테슬라', 13), ('트럼프', 12), ('기대', 12), ('상승', 11), ('코스피', 10), ('전쟁', 10), ('종목', 10)]

# %% [markdown]
# #### 상위명사 추출

# %%
top50 = dict(counter.most_common(50))  # 가장 많이 등장한 50개 단어만 추출하여 딕셔너리 생성

# %% [markdown]
# #### 한글 폰트 설정 및 워드클라우드 시각화

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import random

#그래프 스타일
plt.style.use('ggplot')

import matplotlib as mpl

# 한글 폰트 설정
mpl.rcParams['font.family'] = 'Malgun Gothic'

# 마이너스 깨짐 방지
mpl.rcParams['axes.unicode_minus'] = False

font_path = 'C:\\Windows\\Fonts\\Hancom Gothic Regular.ttf'  # 한글 폰트 경로

cmap = cm.get_cmap('YlGn')

def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    value = random.uniform(0.3, 1.0)
    r, g, b, _ = cmap(value)
    return f"rgb({int(r*255)}, {int(g*255)}, {int(b*255)})"

wc = WordCloud(
    font_path=font_path,
    background_color='white',
    width=800,
    height=600,
    color_func=color_func,
    max_font_size=180,
    scale=2
)

# 워드클라우드 생성
cloud = wc.generate_from_frequencies(top50)

# 시각화 + 타이틀
plt.figure(figsize=(10, 8))
plt.imshow(cloud, interpolation='bilinear')
plt.axis('off')

# ✅ 타이틀 추가 (더 크고 위쪽에 배치)
plt.title("모든페이지", fontsize=26, color='dimgray', weight='bold')
plt.subplots_adjust(top=0.88)  # 타이틀 위치 조정 (더 위로)

plt.tight_layout(pad=1)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15340\967007087.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('YlGn')

# %%
from matplotlib import font_manager

# 시스템에 설치된 모든 폰트 리스트 가져오기
font_list = font_manager.findSystemFonts(fontpaths=None, fontext='ttf')

# 한글 폰트만 필터링 (이름에 'Malgun', 'Gothic', 'Nanum', 'Apple' 등 포함)
korean_fonts = [f for f in font_list if 'malgun' in f.lower() or
                                         'gothic' in f.lower() or
                                         'nanum' in f.lower() or
                                         'apple' in f.lower()]

# 결과 확인
for font in korean_fonts:
    print(font)
# Out:
# C:\Windows\Fonts\GOTHICBI.TTF
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\Gong Gothic Medium.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\Gong Gothic Light.ttf
# C:\Windows\Fonts\NanumGothicLight.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumSquareRoundL.ttf
# C:\Windows\Fonts\NanumMyeongjo.ttf
# C:\Windows\Fonts\NanumGothic.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumSquareR.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumPen.ttf
# C:\Windows\Fonts\Hancom Gothic Regular.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumBarunGothic.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumGothicExtraBold.ttf
# C:\Windows\Fonts\GOTHICI.TTF
# C:\Windows\Fonts\GOTHICB.TTF
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumBarunpenB.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumGothic.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumSquareRoundR.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumSquareB.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumSquareL.ttf
# C:\Windows\Fonts\malgun.ttf
# C:\Windows\Fonts\msgothic.ttc
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumSquare_0.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumSquareEB.ttf
# C:\Windows\Fonts\Hancom Gothic Bold.ttf
# C:\Windows\Fonts\GOTHIC.TTF
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\Gong Gothic Bold.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumSquare_acL.ttf
# C:\Windows\Fonts\malgunsl.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumSquare.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumBarunpenR.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumSquareRoundB.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumBarunGothicBold.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumBarunGothicLight.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumMyeongjo.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumBrush.ttf
# C:\Windows\Fonts\malgunbd.ttf
# C:\Windows\Fonts\NanumGothicBold.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumSquareRoundEB.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumGothicLight.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumBarunGothicUltraLight.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumSquare_acR.ttf
# C:\Windows\Fonts\NanumMyeongjoExtraBold.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumMyeongjoBold.ttf
# C:\Windows\Fonts\NanumGothicExtraBold.ttf
# C:\Windows\Fonts\NanumMyeongjoBold.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumMyeongjoExtraBold.ttf
# C:\Users\User\AppData\Local\Microsoft\Windows\Fonts\NanumGothicBold.ttf
