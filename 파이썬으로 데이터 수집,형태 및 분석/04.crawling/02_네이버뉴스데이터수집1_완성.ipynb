# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from datetime import datetime
import time

# ----------------------------------
# 날짜 입력받기
#   -> 입력하지 않으면 오늘날짜 반환
#   -> 잘못된 형식이면 None 반환
# ----------------------------------
def date_input():

    date_str = input("날짜:(형식:2020-01-05)")
    
    if date_str=="":
        date_str = datetime.now().strftime('%Y-%m-%d')
    
    try:
        datetime.strptime(date_str, '%Y-%m-%d')
    except:
        print("날짜 형색이 올바르지 않습니다.")
        date_str = None
    
    return date_str

date = date_input()

# %%
# ----------------------------------
# 웹페이지 요청하여 응답객체 반환
# ----------------------------------
url = 'https://finance.naver.com/news/mainnews.naver?date='+date
response = requests.get(url)
    
# ----------------------------------
# 웹페이지 파싱하여 BeautifulSoup 객체 반환
# ----------------------------------
soup = BeautifulSoup(response.text, 'html.parser')

# ----------------------------------
# article 리스트 추출
# ----------------------------------   
articles = soup.select(".block1")

# ----------------------------------
# article 리스트에서 요소의 텍스트, 속성 추출
# ----------------------------------   
data = []
for article in articles:
    title = article.select_one(".articleSubject>a").text
    summary = article.select_one(".articleSummary").contents[0].text.strip()
    press = article.select_one(".press").text.strip()
    wdate = article.select_one(".wdate").text.strip()
    link = article.select_one(".articleSubject>a").attrs['href']
    article_id = link.split('=')[1].split('&')[0]
    office_id = link.split('office_id=')[1].split('&')[0]
    link = f'https://n.news.naver.com/mnews/article/{office_id}/{article_id}'
    
    data.append({"title":title, "summary":summary, "press":press, "wdate":wdate, "link":link})

# %%
df = pd.DataFrame(data)
df
# Out:
#                                          title  \
# 0          PBR 0.1 기업 정리한다는데…청산 가치보다 낮은 기업 어디?
# 1               달러 가치 회복 나선 미국…지속되는 환율 ‘레인지 장’
# 2              ‘머스크 복귀 예고’에 테슬라 이어 韓 2차전지주도 강세
# 3       금감원 제동에도 유증 재도전 나선 스맥, 다윗의 골리앗 인수 가능할까
# 4              5년만에 역성장...편의점, 해외 노린다 [마켓딥다이브]
# 5           트럼프 관세전쟁에 '셀 아메리카'…유럽펀드로 갈아타는 투자자들
# 6             증여 소식에 한미반도체 13% 상승 '훨훨' [줍줍리포트]
# 7       "풍산, 나홀로 저평가…인적분할 시 기업가치 두 배 뛴다"[마켓칼럼]
# 8            "주가 변동률 120%"…정치인 테마주 과열에 '강력 경고'
# 9               BYD에 밀린 테슬라…머스크 컴백에도 불안 [테크톡톡]
# 10      "점심시간 1시간 엄수" 공지에…여의도 증권맨들 '초긴장' [돈앤톡]
# 11                   테슬라 시간외 급등에…국내 이차전지株 '들썩'
# 12   투자경고 이상 종목 중 절반이 '정치테마주'…121% 변동에 '투자주의보'
# 13          과열된 정치 테마주 폭등락… 거래소 “불공정거래, 강력 대처”
# 14               최상목 매수 논란 미국 채권…일본은 팔고 한국은 사고
# 15           '나홀로 돈 벌었다'…중국 탈출 러시에 '대피처'로 뜬 나라
# 16                    "저가매수 신중해라"…과도한 낙관은 '금물'
# 17                 "진정한 바닥 오지 않았다"…추가 하락 '경고등'
# 18  땡큐 트럼프! 中 협상 가능성에 가상자산 환호…비트코인 9만3000달러 돌파
# 19              9.3만弗 회복한 비트코인...금 따라갈까 [매일코인]
#
#                                               summary   press  \
# 0   수년째 박스권에 갇힌 국내 증시에서 국장은 호재에는 둔감하고 악재에 민감하다는 자조...   머니투데이
# 1   미국이 중국과의 무역전쟁과 ‘파월 흔들기’에서 벗어나 달러화 가치 회복에 나섰다. ...    이데일리
# 2   일론 머스크 최고경영자(CEO)가 경영 전선에 복귀한다고 밝히자 테슬라에 이어 국내...    매일경제
# 3   스맥·릴슨PE, 현대위아 공작기계사업부 인수전 총 인수대금 3400억원 필요해 스맥...    매일경제
